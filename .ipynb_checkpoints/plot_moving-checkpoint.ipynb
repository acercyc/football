# %%
# %matplotlib notebook
import football.lib as fb
import pandas as pd

d = pd.read_csv('valid_data/2016022707_player.csv')
fb.plot_moving_playerBased(d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-91055e68f174> in <module>()
#       3
#       4 d = pd.read_csv('valid_data/2016022707_player.csv')
# ----> 5 fb.plot_moving_playerBased(d)
#
# /home/acercyc/Project_Araya/football/football/lib.py in plot_moving_playerBased(d, timeStep)
#     169         ax.set_ylim(dataInfo.fieldSize_y)
#     170
# --> 171         fig.canvas.draw()
#     172         ax.cla()
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
# ...
