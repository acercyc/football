# %%
# %matplotlib notebook
import football.lib as fb
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
d = pd.read_csv('valid_data/2016022707_player.csv')

# %%
fb.plot_moving_playerBased(d)
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3d19e579f79c> in <module>()
#       5
#       6 d = pd.read_csv('valid_data/2016022707_player.csv')
# ----> 7 fb.plot_moving_playerBased(d)
#
# /home/acercyc/Project_Araya/football/football/lib.py in plot_moving_playerBased(d, timeStep)
#     170
#     171         fig.canvas.draw()
# --> 172         ax.cla()
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/axes/_base.py in cla(self)
#     914         self.yaxis.cla()
#     915         for name, spine in six.iteritems(self.spines):
# --> 916             spine.cla()
#     917
#     918         self.ignore_existing_data_limits = True
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/spines.py in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/axis.py in cla(self)
#     742         self._set_artist_props(self.label)
#     743
# --> 744         self.reset_ticks()
#     745
#     746         self.converter = None
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/axis.py in reset_ticks(self)
#     757
#     758         self.majorTicks.extend([self._get_tick(major=True)])
# --> 759         self.minorTicks.extend([self._get_tick(major=False)])
#     760         self._lastNumMajorTicks = 1
#     761         self._lastNumMinorTicks = 1
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1675         else:
#    1676             tick_kw = self._minor_tick_kw
# -> 1677         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1678
#    1679     def _get_label(self):
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     400                           linestyle='None', marker=self._tickmarkers[0],
#     401                           markersize=self._size,
# --> 402                           markeredgewidth=self._width, zorder=self._zorder)
#     403         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     404         self._set_artist_props(l)
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     351         self._color = None
#     352         self.set_color(color)
# --> 353         self._marker = MarkerStyle()
#     354         self.set_marker(marker)
#     355
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     169         # _recache() in set_marker.
#     170         self._fillstyle = fillstyle
# --> 171         self.set_marker(marker)
#     172         self.set_fillstyle(fillstyle)
#     173
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     253
#     254         self._marker = marker
# --> 255         self._recache()
#     256
#     257     def get_path(self):
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/markers.py in _recache(self)
#     184     def _recache(self):
#     185         self._path = Path(np.empty((0, 2)))
# --> 186         self._transform = IdentityTransform()
#     187         self._alt_path = None
#     188         self._alt_transform = None
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/transforms.py in __init__(self, *args, **kwargs)
#    1639
#    1640     def __init__(self, *args, **kwargs):
# -> 1641         Transform.__init__(self, *args, **kwargs)
#    1642         self._inverted = None
#    1643
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/transforms.py in __init__(self, shorthand_name)
#      96         # parents are deleted, references from the children won't keep
#      97         # them alive.
# ---> 98         self._parents = WeakValueDictionary()
#      99
#     100         # TransformNodes start out as invalid until their values are
#
# /home/acercyc/env/env_1_p34/lib/python3.4/weakref.py in __init__(self, *args, **kw)
#     100
#     101     def __init__(self, *args, **kw):
# --> 102         def remove(wr, selfref=ref(self)):
#     103             self = selfref()
#     104             if self is not None:
#
# KeyboardInterrupt:

# %%
d_posi = d.ix[:, 'H1X':'A11Y']
posi_diff = np.sum( abs(np.diff(d_posi, axis = 0)), axis=1 )


iNewSession = np.array((posi_diff > 1000).nonzero())[0]+1
iNewSession = np.insert(iNewSession, 0, 0)


d['isNewSession'] = 0
d.ix[iNewSession, 'isNewSession'] = 1
# Out:
# <function ndarray.nonzero>

# %%
fb.addIsNewSession(d)
# Out:
#        Unnamed: 0  Unnamed: 0.1    Frame        Time     H1X     H2X     H3X  \
# 0               0           212  1673565    0.512000 -2414.0  -872.0 -1338.0
# 1               1           213  1673566    0.512667 -2414.0  -869.0 -1339.0
# 2               2           214  1673567    0.513333 -2415.0  -867.0 -1340.0
# 3               3           215  1673568    0.514000 -2416.0  -864.0 -1341.0
# 4               4           216  1673569    0.514667 -2418.0  -859.0 -1342.0
# 5               5           217  1673570    0.515333 -2419.0  -855.0 -1344.0
# 6               6           218  1673571    0.516000 -2421.0  -850.0 -1345.0
# 7               7           219  1673572    0.516667 -2423.0  -844.0 -1348.0
# 8               8           220  1673573    0.517333 -2426.0  -838.0 -1349.0
# 9               9           221  1673574    0.518000 -2429.0  -831.0 -1349.0
# 10             10           222  1673575    0.518667 -2432.0  -825.0 -1350.0
# 11             11           223  1673576    0.519333 -2434.0  -816.0 -1350.0
# 12             12           224  1673577    0.520000 -2438.0  -807.0 -1350.0
# 13             13           225  1673578    0.520667 -2440.0  -799.0 -1350.0
# 14             14           226  1673579    0.521333 -2443.0  -790.0 -1349.0
# 15             15           227  1673580    0.522000 -2445.0  -781.0 -1348.0
# 16             16           228  1673581    0.522667 -2448.0  -773.0 -1346.0
# 17             17           229  1673582    0.523333 -2452.0  -765.0 -1344.0
# 18             18           230  1673583    0.524000 -2455.0  -759.0 -1343.0
# 19             19           231  1673584    0.524667 -2460.0  -754.0 -1340.0
# 20             20           232  1673585    0.525333 -2463.0  -749.0 -1336.0
# 21             21           233  1673586    0.526000 -2466.0  -747.0 -1333.0
# 22             22           234  1673587    0.526667 -2470.0  -745.0 -1330.0
# 23             23           235  1673588    0.527333 -2472.0  -744.0 -1325.0
# 24             24           236  1673589    0.528000 -2475.0  -744.0 -1320.0
# 25             25           237  1673590    0.528667 -2478.0  -745.0 -1315.0
# 26             26           238  1673591    0.529333 -2480.0  -746.0 -1310.0
# 27             27           239  1673592    0.530000 -2482.0  -748.0 -1304.0
# 28             28           240  1673593    0.530667 -2485.0  -751.0 -1300.0
# 29             29           241  1673594    0.531333 -2486.0  -756.0 -1294.0
# ...           ...           ...      ...         ...     ...     ...     ...
# 98237       98237        144206  1840377  111.720000 -2650.0 -3931.0 -3142.0
# 98238       98238        144207  1840378  111.720667 -2644.0 -3924.0 -3142.0
# 12    -1200.0 -2382.0   353.0      ...               -45.0        -1740.0
# 13    -1198.0 -2384.0   354.0      ...               -45.0        -1738.0
# 14    -1194.0 -2388.0   356.0      ...               -44.0        -1737.0
# 15    -1191.0 -2391.0   359.0      ...               -44.0        -1736.0
# 16    -1187.0 -2394.0   361.0      ...               -44.0        -1734.0
# 17    -1183.0 -2398.0   363.0      ...               -43.0        -1734.0
# 18    -1180.0 -2401.0   365.0      ...               -43.0        -1733.0
# 19    -1175.0 -2403.0   367.0      ...               -42.0        -1734.0
# 20    -1170.0 -2406.0   370.0      ...               -41.0        -1734.0
# 21    -1167.0 -2409.0   371.0      ...               -40.0        -1734.0
# 22    -1162.0 -2411.0   373.0      ...               -40.0        -1734.0
# 23    -1158.0 -2412.0   375.0      ...               -39.0        -1734.0
# 24    -1154.0 -2412.0   377.0      ...               -39.0        -1734.0
# 25    -1150.0 -2413.0   380.0      ...               -39.0        -1733.0
# 26    -1146.0 -2414.0   382.0      ...               -39.0        -1732.0
# 27    -1141.0 -2414.0   384.0      ...               -38.0        -1731.0
# 28    -1136.0 -2415.0   386.0      ...               -37.0        -1730.0
# 29    -1130.0 -2415.0   387.0      ...               -37.0        -1728.0
# ...       ...     ...     ...      ...                 ...            ...
# 98237 -2290.0 -3849.0 -3907.0      ...               663.0          912.0
# 98238 -2280.0 -3836.0 -3894.0      ...               663.0          923.0
# 98239 -2270.0 -3824.0 -3881.0      ...               663.0          941.0
# 98240 -2260.0 -3811.0 -3868.0      ...               662.0          960.0
# 98241 -2250.0 -3797.0 -3856.0      ...               664.0          981.0
# 98242 -2241.0 -3785.0 -3846.0      ...               667.0         1001.0
# 98243 -2230.0 -3772.0 -3835.0      ...               667.0         1018.0
# 98244 -2221.0 -3758.0 -3823.0      ...               668.0         1036.0
# 98245 -2212.0 -3747.0 -3812.0      ...               668.0         1053.0
# 98246 -2203.0 -3736.0 -3800.0      ...               667.0         1069.0
# 98247 -2194.0 -3726.0 -3790.0      ...               668.0         1084.0
# 98248 -2186.0 -3716.0 -3777.0      ...               665.0         1101.0
# 98249 -2179.0 -3706.0 -3767.0      ...               665.0         1115.0
# 98250 -2170.0 -3695.0 -3758.0      ...               664.0         1128.0
# 98251 -2163.0 -3684.0 -3751.0      ...               664.0         1137.0
# 98252 -2157.0 -3674.0 -3744.0      ...               662.0         1146.0
# 98253 -2150.0 -3664.0 -3737.0      ...               660.0         1155.0
# 98254 -2142.0 -3655.0 -3731.0      ...               661.0         1161.0
# 98255 -2137.0 -3647.0 -3724.0      ...               662.0         1162.0
# 98256 -2130.0 -3637.0 -3717.0      ...               664.0         1162.0
# 98257 -2125.0 -3627.0 -3712.0      ...               663.0         1158.0
# 98258 -2119.0 -3616.0 -3706.0      ...               660.0         1156.0
# 98259 -2115.0 -3608.0 -3701.0      ...               656.0         1151.0
# 98260 -2108.0 -3598.0 -3694.0      ...               650.0         1144.0
# 98259         -583.0          364.0            NaN        -116.0
# 98260         -587.0          363.0            NaN        -120.0
# 98261         -591.0          358.0            NaN        -124.0
# 98262         -595.0          355.0            NaN        -128.0
# 98263         -598.0          348.0            NaN        -132.0
# 98264         -600.0          346.0            NaN        -136.0
# 98265         -604.0          345.0            NaN        -141.0
# 98266         -606.0          345.0            NaN        -144.0
#
#        player_Y_H_6  player_Y_H_7  player_Y_H_8  isNewSession
# 0            -249.0       -2092.0           NaN             1
# 1            -250.0       -2092.0           NaN             0
# 2            -250.0       -2092.0           NaN             0
# 3            -248.0       -2092.0           NaN             0
# 4            -247.0       -2092.0           NaN             0
# 5            -249.0       -2092.0           NaN             0
# 6            -249.0       -2091.0           NaN             0
# 7            -248.0       -2092.0           NaN             0
# 8            -248.0       -2092.0           NaN             0
# 9            -247.0       -2093.0           NaN             0
# 10           -246.0       -2094.0           NaN             0
# 11           -244.0       -2093.0           NaN             0
# 12           -242.0       -2093.0           NaN             0
# 13           -241.0       -2091.0           NaN             0
# 14           -240.0       -2089.0           NaN             0
# 15           -241.0       -2088.0           NaN             0
# 16           -241.0       -2087.0           NaN             0
# 17           -239.0       -2086.0           NaN             0
# 18           -237.0       -2085.0           NaN             0
# 19           -231.0       -2084.0           NaN             0
# 20           -226.0       -2082.0           NaN             0
# 21           -221.0       -2080.0           NaN             0
# 22           -212.0       -2079.0           NaN             0
# 23           -203.0       -2078.0           NaN             0
# 24           -196.0       -2075.0           NaN             0
# 25           -188.0       -2073.0           NaN             0
# 26           -180.0       -2070.0           NaN             0
# 27           -174.0       -2067.0           NaN             0
# 28           -168.0       -2064.0           NaN             0
# 29           -161.0       -2063.0           NaN             0
# ...             ...           ...           ...           ...
# 98237           NaN           NaN        -550.0             0
# 98238           NaN           NaN        -554.0             0
# 98239           NaN           NaN        -555.0             0
# 98240           NaN           NaN        -558.0             0
# 98241           NaN           NaN        -559.0             0
# 98242           NaN           NaN        -561.0             0
# 98243           NaN           NaN        -562.0             0
# 98244           NaN           NaN        -563.0             0
# 98245           NaN           NaN        -564.0             0
# 98246           NaN           NaN        -566.0             0
# 98247           NaN           NaN        -568.0             0
# 98248           NaN           NaN        -569.0             0
# 98249           NaN           NaN        -570.0             0
# 98250           NaN           NaN        -570.0             0
# 98251           NaN           NaN        -570.0             0
# 98252           NaN           NaN        -570.0             0
# 98253           NaN           NaN        -569.0             0
# 98254           NaN           NaN        -569.0             0
# 98255           NaN           NaN        -570.0             0
# 98256           NaN           NaN        -573.0             0
# 98257           NaN           NaN        -574.0             0
# 98258           NaN           NaN        -576.0             0
# 98259           NaN           NaN        -576.0             0
# 98260           NaN           NaN        -576.0             0
# 98261           NaN           NaN        -577.0             0
# 98262           NaN           NaN        -578.0             0
# 98263           NaN           NaN        -579.0             0
# 98264           NaN           NaN        -580.0             0
# 98265           NaN           NaN        -581.0             0
# 98266           NaN           NaN        -582.0             0
#
# [98267 rows x 162 columns]
