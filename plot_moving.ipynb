# %%
# %matplotlib notebook
import football.lib as fb
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
d = pd.read_csv('valid_data/2016022707_player.csv')

# %%
fb.plot_moving_playerBased(d)
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7b901506ce0f> in <module>()
# ----> 1 fb.plot_moving_playerBased(d)
#
# /home/acercyc/Project_Araya/football/football/lib.py in plot_moving_playerBased(d, timeStep)
#     219         ax.set_ylim(dataInfo.fieldSize_y)
#     220
# --> 221         fig.canvas.draw()
#     222         ax.cla()
#     223
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     177         backend_agg.RendererAgg.lock.acquire()
#     178         try:
# --> 179             self.figure.draw(renderer)
#     180         finally:
#     181             backend_agg.RendererAgg.lock.release()
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
# ...

# %% [markdown]
# ## Plot session transition indicator

# %%
d = fb.addIsNewSession(d)

# %%
fb.plot_moving_playerBased(d, isPlotSessionBreak=True)
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-c95b08941ff3> in <module>()
# ----> 1 fb.plot_moving_playerBased(d, isPlotSessionBreak=True)
#
# /home/acercyc/Project_Araya/football/football/lib.py in plot_moving_playerBased(d, timeStep, isPlotSessionBreak)
#     235
#     236         fig.canvas.draw()
# --> 237         ax.cla()
#     238
#     239
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/axes/_base.py in cla(self)
#     914         self.yaxis.cla()
#     915         for name, spine in six.iteritems(self.spines):
# --> 916             spine.cla()
#     917
#     918         self.ignore_existing_data_limits = True
#
# /home/acercyc/env/env_1_p34/lib/python3.4/site-packages/matplotlib/spines.py in cla(self)
#     168         self._position = None  # clear position
# ...
